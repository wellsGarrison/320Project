# %% [markdown]
# # **Final Project: Checkpoint 2**
# (5 points) Data preprocessing: (a) import, (b) parse (e.g., convert strings to ints), (c) organize (e.g., set up a database or a pandas DataFrame).
#
# (20 points) Basic data exploration and summary statistics
#  - You must present three conclusions using at least three different statistical
# methods including hypothesis testing.
#     - For example: What are the main characteristics of your dataset? How
# many features and entries are there? Is a feature over-represented? Are
# features correlated? Are there outliers? Identify the attributes that will
# affect your choice of primary analysis technique. Etcetera.
#  - For each method, you must have at least one gorgeous plot.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
# https://www.fec.gov/data/candidates/president/presidential-map/ 
# spending - allcandidates 
spending_df = pd.read_csv("spending_data.csv", index_col=False)
spending_df
# Out:
# /tmp/ipykernel_4917/2008950849.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   spending_df = pd.read_csv("spending_data.csv", index_col=False)
#           cmte_id    cand_id              cand_nm                recipient_nm  \
# 0       C00540302  P40012155    Scott, Timothy E.   THREE ARBOR INSURANCE INC
# 1       C00540302  P40012155    Scott, Timothy E.   THREE ARBOR INSURANCE INC
# 2       C00540302  P40012155    Scott, Timothy E.                     WALMART
# 3       C00540302  P40012155    Scott, Timothy E.                     WALMART
# 4       C00540302  P40012155    Scott, Timothy E.                     WALMART
# ...           ...        ...                  ...                         ...
# 112107  C00867812  P40019218  Terry, Randal Allan  MOUNT JACKSON TRUCK CENTER
# 112108  C00867812  P40019218  Terry, Randal Allan           SWEETWATER TAVERN
# 112109  C00867812  P40019218  Terry, Randal Allan               GABRIEL, MARK
# 112110  C00867812  P40019218  Terry, Randal Allan               GABRIEL, MARK
# 112111  C00867812  P40019218  Terry, Randal Allan               GABRIEL, MARK
#
#         disb_amt    disb_dt recipient_city recipient_st recipient_zip  \
# 0       26630.07  31-AUG-23       VESTAVIA           AL         35243
# 1       10342.13  15-SEP-23       VESTAVIA           AL         35243
# 2          10.60  28-JUN-23    BENTONVILLE           AR         72716
# 3         152.88  15-SEP-23    BENTONVILLE           AR         72716
# 4         218.00  15-SEP-23    BENTONVILLE           AR         72716
# ...          ...        ...            ...          ...           ...
# 112107    219.11  29-JUL-24  MOUNT JACKSON           VA         22842
# 112108    215.41  08-AUG-24    CENTREVILLE           WA         20121
# 112109    153.75  30-JUN-24       APPLETON           WI         54915
# 112110    316.25  01-AUG-24       APPLETON           WI         54915
# 112111    152.50  14-JUN-24       APPLETON           WI         54915
#
#               disb_desc memo_cd memo_text form_tp  file_num          tran_id  \
# 0             INSURANCE     NaN       NaN    SB23   1731524      SB23.960154
# 1             INSURANCE     NaN       NaN    SB23   1731524      SB23.960155
# 2       OFFICE SUPPLIES       X       NaN    SB23   1731524  SB23.951080.003
# 3       OFFICE SUPPLIES       X       NaN    SB23   1731524  SB23.966491.284
# 4       OFFICE SUPPLIES       X       NaN    SB23   1731524  SB23.966491.285
# ...                 ...     ...       ...     ...       ...              ...
# 112107     FOOD/SHOWERS     NaN       NaN    SB23   1812531        SB23.6419
# 112108             FOOD     NaN       NaN    SB23   1816947        SB23.6524
# 112109     FUND RAISING     NaN       NaN    SB23   1804884        SB23.5890
# 112110      FUNDRAISING     NaN       NaN    SB23   1816947        SB23.6464
# 112111     FUND RAISING     NaN       NaN    SB23   1804884        SB23.5888
#
#        election_tp
# 0            P2024
# 1            P2024
# 2            P2024
# 3            P2024
# 4            P2024
# ...            ...
# 112107       G2024
# 112108       G2024
# 112109       G2024
# 112110       G2024
# 112111       G2024
#
# [112112 rows x 16 columns]

# %%
cand_info = pd.read_csv("weball24.txt", delimiter='|')
cand_info
# Out:
#         CAND_ID                   CAND_NAME CAND_ICI  PTY_CD  \
# 0     H2AK00200       CONSTANT, CHRISTOPHER        C       1
# 1     H2AK01158               PELTOLA, MARY        I       1
# 2     H2AK00226                PALIN, SARAH        O       2
# 3     H2AK01083        BEGICH, NICHOLAS III        C       2
# 4     H4AK00156            DAHLSTROM, NANCY        C       2
# ...         ...                         ...      ...     ...
# 3792  S4WV00423             LINDSAY, DONALD        O       2
# 3793  S4WY00188          MORROW, SCOTT D MR        C       1
# 3794  S0WY00137  LUMMIS, CYNTHIA MARIE MRS.        I       2
# 3795  S4WY00162                RASNER, REID        C       2
# 3796  S6WY00068            BARRASSO, JOHN A        I       2
#
#      CAND_PTY_AFFILIATION  TTL_RECEIPTS  TRANS_FROM_AUTH    TTL_DISB  \
# 0                     DEM          0.00             0.00        0.00
# 1                     DEM   10668705.84        617668.60  8324352.37
# 2                     REP       3866.49             0.00    50246.07
# 3                     REP    1789869.45        112470.80  1390345.73
# 4                     REP     982395.15        423333.44   781568.25
# ...                   ...           ...              ...         ...
# 3792                  REP       9792.33             0.00     9792.33
# 3793                  DEM      36054.82             0.00     4439.65
# 3794                  REP     546175.07        111073.95   195781.29
# 3795                  REP    1304150.64             0.00  1294697.64
# 3796                  REP    7304198.72       1243302.04  3398221.67
#
#       TRANS_TO_AUTH     COH_BOP  ...  SPEC_ELECTION  PRIM_ELECTION  \
# 0              0.00        0.00  ...            NaN            NaN
# 1              0.00   691260.30  ...            NaN            NaN
# 2              0.00    46379.58  ...            NaN            NaN
# 3          17659.66    41233.99  ...            NaN            NaN
# 4              0.00        0.00  ...            NaN            NaN
# ...             ...         ...  ...            ...            ...
# 3792           0.00        0.00  ...            NaN            NaN
# 3793        2200.00        0.00  ...            NaN            NaN
# 3794        5000.00   115856.76  ...            NaN            NaN
# 3795           0.00        0.00  ...            NaN            NaN
# 3796           0.00  4487576.49  ...            NaN            NaN
#
#       RUN_ELECTION  GEN_ELECTION  GEN_ELECTION_PRECENT  \
# 0              NaN           NaN                   NaN
# 1              NaN           NaN                   NaN
# 2              NaN           NaN                   NaN
# 3              NaN           NaN                   NaN
# 4              NaN           NaN                   NaN
# ...            ...           ...                   ...
# 3792           NaN           NaN                   NaN
# 3793           NaN           NaN                   NaN
# 3794           NaN           NaN                   NaN
# 3795           NaN           NaN                   NaN
# 3796           NaN           NaN                   NaN
#
#       OTHER_POL_CMTE_CONTRIB  POL_PTY_CONTRIB  CVG_END_DT INDIV_REFUNDS  \
# 0                       0.00             0.00  09/30/2024          0.00
# 1                 1385214.20          7208.83  09/30/2024     112286.11
# 2                       0.00             0.00  03/31/2023      -9152.50
# 3                  117050.00          5000.00  09/30/2024      10535.00
# 4                  262916.02             0.00  09/30/2024       3135.00
# ...                      ...              ...         ...           ...
# 3792                    0.00             0.00  06/30/2024          0.00
# 3793                 5000.00          1000.00  09/30/2024          0.00
# 3794               220084.83             0.00  09/30/2024       8850.00
# 3795                    0.00             0.00  09/30/2024          0.00
# 3796              2577770.00             0.00  09/30/2024      45724.43
#
#       CMTE_REFUNDS
# 0             0.00
# 1          2500.00
# 2             0.00
# 3             0.00
# 4             0.00
# ...            ...
# 3792          0.00
# 3793          0.00
# 3794          0.00
# 3795          0.00
# 3796       5215.26
#
# [3797 rows x 30 columns]

# %%
poll_data = pd.read_csv("presidential_general_averages.csv")
poll_data
# Out:
#                  candidate        date  pct_trend_adjusted      state  cycle  \
# 0      Joseph R. Biden Jr.  2020-11-03            37.82732    Alabama   2020
# 1             Donald Trump  2020-11-03            57.36126    Alabama   2020
# 2      Joseph R. Biden Jr.  2020-11-02            37.82732    Alabama   2020
# 3             Donald Trump  2020-11-02            57.36126    Alabama   2020
# 4      Joseph R. Biden Jr.  2020-11-01            38.07011    Alabama   2020
# ...                    ...         ...                 ...        ...    ...
# 28526              Kennedy  2024-03-02                 NaN  Wisconsin   2024
# 28527                Biden  2024-03-02                 NaN  Wisconsin   2024
# 28528                Trump  2024-03-01                 NaN  Wisconsin   2024
# 28529              Kennedy  2024-03-01                 NaN  Wisconsin   2024
# 28530                Biden  2024-03-01                 NaN  Wisconsin   2024
#
#       party  pct_estimate         hi         lo
# 0       NaN           NaN        NaN        NaN
# 1       NaN           NaN        NaN        NaN
# 2       NaN           NaN        NaN        NaN
# 3       NaN           NaN        NaN        NaN
# 4       NaN           NaN        NaN        NaN
# ...     ...           ...        ...        ...
# 28526   IND      10.28615  12.852725   7.514286
# 28527   DEM      38.73255  41.180613  36.214855
# 28528   REP      41.58205  43.986072  39.224702
# 28529   IND      10.30900  13.044215   7.668578
# 28530   DEM      38.85280  41.241032  36.374370
#
# [28531 rows x 9 columns]
